# %% [markdown]
# ### Test Azure Deployment

# %% [markdown]
# Click the button below to deploy all required resources to your Azure subscription:
#
# [![Deploy to Azure](https://aka.ms/deploytoazurebutton)](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Faep-microsoft%2Faurora_mpc_workflow%2Fmain%2Fdeploy%2Fazuredeploy.json)
